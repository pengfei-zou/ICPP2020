# %%
import os
import sys
import re
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import openpyxl
import pandas as pd
import math
import itertools
import matplotlib.patches as patches
import seaborn as sns
from decimal import Decimal
from csv import reader
import csv
from tsfresh import extract_features
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
import glob

def get_app_list(fileName):
    """get metrics list

    Arguments:
        fileName {string} -- the file name of application file with absolute path

    Returns:
        app {list} -- the app  list
    """
    apps = []
    with open(fileName) as f:
        for line in f.readlines():
            if not line.startswith('#'):
                words = line.strip().split(',')
                app = words[0].strip()
                app_num = words[1].strip()
                apps.append(app+app_num)
        f.close()
    return apps

def trace_read_C(fileName, kernel_outName, transfer_outName):
    # index
    start       = 0
    duration    = 0
    thread_size        = 0
    throughtput = 0
    device      = 0
    context     = 0
    stream      = 0
    name        = 0

    with open(fileName) as f:
        reader = csv.reader(f, delimiter=',')
        for row in reader:
            #print(row)
            if ('Start' in row):
                if ('Throughput' not in row):
                    return [-1,-1,-1,-1] 
                #print(row)
                start      = row.index('Start')
                duration   = row.index('Duration')
                grid_x     = row.index('Grid X')
                grid_y     = row.index('Grid Y')
                grid_z     = row.index('Grid Z')
                block_x     = row.index('Block X')
                block_y     = row.index('Block Y')
                block_z     = row.index('Block Z')
                name       = row.index('Name')
                throughput = row.index('Throughput')

                break
               
        ndev = 0
        row = []
        for r in reader:
            row.append(r)
        
        time = 0.0
        time_K = 0.0
        time_H_D = 0.0
        time_D_H = 0.0
        time_D_D = 0.0
        transfer_trace = []
        kernel_trace = []
        for i in range(len(row)):
            if (len(row[i]) > 10 and row[i][start] != 'Start' and not 's' in row[i][start]):
                if 'HtoD' in row[i][name] :
                    time_H_D += float(row[i][duration])
                    if row[i][throughput] =='':
                        continue
                    transfer_trace.append([float(row[i][start]), float(row[i][duration]), 0, float(row[i][throughput])])
                elif 'DtoH' in row[i][name]  :
                    if row[i][throughput] =='':
                        continue
                    time_D_H += float(row[i][duration])
                    transfer_trace.append([float(row[i][start]), float(row[i][duration]), 1, float(row[i][throughput])])
                elif 'DtoD' in row[i][name]  :
                    if row[i][throughput] =='':
                        continue
                    time_D_H += float(row[i][duration])
                    transfer_trace.append([float(row[i][start]), float(row[i][duration]), 2, float(row[i][throughput])])
                elif 'CUDA memset' in row[i][name] or 'CUDA memcpy' in row[i][name] or 'Unified Memory' in row[i][name]:
                    continue
                
                else:
                    if len(row[i][duration]):
                        #print(row[i])
                        time_K += float(row[i][duration])
                        kernel_trace.append([float(row[i][start]), float(row[i][duration]),
                                             float(row[i][grid_x])*float(row[i][block_x]),
                                             float(row[i][grid_y])*float(row[i][block_y]),
                                             float(row[i][grid_z])* float(row[i][block_z])])
        time = time_K + time_D_D + time_D_H + time_H_D
        with open(transfer_outName, "w", newline='') as csvfile:
            csvwriter = csv.writer(csvfile, delimiter=',')
            csvwriter.writerow(["start", "duration", "direction", "throughput"])
            for i in range(len(transfer_trace)):
                csvwriter.writerow(transfer_trace[i])
            csvfile.close()

        with open(kernel_outName, "w", newline='') as csvfile:
            csvwriter = csv.writer(csvfile, delimiter=',')
            csvwriter.writerow(["start", "duration", "threads_x", "threads_y", "threads_z"])
            for i in range(len(kernel_trace)):
                csvwriter.writerow(kernel_trace[i])
            csvfile.close()
            
            
        f.close()
    if time == 0:
        return [-1,-1,-1,-1]
    return [time_K, time_H_D, time_D_H, time_D_D]

def trace_read(outFile, app_list, pathfolder):
    data = []
    for app in app_list:
        print(app)
        fileName = os.path.join(pathfolder, "{}.mem_output".format(app))
        if not os.path.exists(fileName):
            print(fileName)
            continue
        kernel_outName = os.path.join(pathfolder, "{}_kernel.csv".format(app))
        transfer_outName = os.path.join(pathfolder, "{}_transfer.csv".format(app))
        temp = trace_read_C(fileName, kernel_outName, transfer_outName)
        temp.insert(0, app)
        data.append(temp)
    columns= ["app", "kernel", "H_D", "D_H", "D_D"]  
    df = pd.DataFrame(data=data, columns=columns)
    #df.to_csv(outFile, index=False )

def transfer_Data(fileName, outFile):
    data = pd.read_excel(fileName) 
    for col in data.columns:
        data = data[data[col] != -1]
    writer = pd.ExcelWriter(outFile,engine='xlsxwriter')
    data.to_excel(writer, sheet_name="mem_trace", index=False)
    writer.save()
def combine_data(pathfolder, app_list, outFile):
    writer = pd.ExcelWriter(outFile,engine='xlsxwriter')
    data = []
    i = 0
    
    for app in app_list:
        fileName =  os.path.join(pathfolder, "{}.csv".format(app))
        data_temp = pd.read_csv(fileName)
        data_temp["app"] = app
        data_temp["ID"] = i
        data.append(data_temp)
        i+=1
        
        if  i%200 == 0:        
            outData = pd.concat(data)    
            outData.to_excel(writer, sheet_name="{}-{}".format(i-199, i), index=False)
            data = []
        elif i==len(app_list):
            if i >= 200:
                x = i -199
            else:
                x=1
            outData = pd.concat(data)    
            outData.to_excel(writer, sheet_name="{}-{}".format(x, i), index=False)
    writer.save()

def extractFeature(dataName, outName):
    xlData = pd.ExcelFile(dataName)
    data = []
    for sheets in xlData.sheet_names:
        dataX = xlData.parse( sheet_name=sheets) 
        data.append(dataX)
    data = pd.concat(data)    
    dataX = data.drop(columns=["app"])
    extracted_features = extract_features(dataX, column_id="ID", column_sort="start")
    extracted_features.to_csv(outName, index=False)


def process_Data(pathfolder, app_list):
    
    memFile = "memRatio-{}-{}.csv".format(category, arch)
    print("start")
    trace_read(memFile, app_list, pathfolder)
    print("end")

if __name__=="__main__":        
    category = "risky"
    for category in ["mybench", "risky"]:#, "risky"]:
        for arch in ["v100"]:#, "v100", "k40"]:
    #arch ="v100"/home/pzou/projects/Power_Signature/results/Turing/mem_trace-combine
            pathfolder = r"/home/pzou/projects/Power_Signature/results_backup/%s/%s/mem_trace-combine"%(category, arch)
            app_list = get_app_list("/home/pzou/projects/Power_Signature/Scripts/applications-mem_%s.csv"%(category))
    
            memFile = "memRatio-{}-{}.csv".format(category, arch)
            print("start")
            trace_read(memFile, app_list, pathfolder)

            combineFile = "{}/mem-{}-{}.xlsx".format(arch,category, arch)
            #combine_data(pathfolder, app_list, combineFile)
            print("end")
# Out:
# start
# alignedTypes1
# alignedTypes2
# alignedTypes3
# alignedTypes4
# alignedTypes5
# alignedTypes6
# alignedTypes7
# alignedTypes8
# alignedTypes9
# alignedTypes10
# atax1
# atax2
# atax3
# atax4
# atax5
# atax6
# atax7
# atax8
# atax9
# atax10
# b+tree1
# b+tree2
# b+tree3
# b+tree4
# b+tree5
# b+tree6
# b+tree7
# b+tree8
# b+tree9
# b+tree10
# b+tree11
# backprop1
# backprop2
# backprop3
# backprop4
# backprop5
# backprop6
# backprop7
# backprop8
# backprop9
# backprop10
# bfs1
# bfs2
# bfs3
# bfs4
# bfs5
# bfs6
# bfs7
# bfs8
# bfs9
# bfs10
# bicg1
# bicg2
# bicg3
# bicg4
# bicg5
# bicg6
# bicg7
# bicg8
# bicg9
# bicg10
# bicg11
# binomialOptions1
# binomialOptions2
# binomialOptions3
# binomialOptions4
# binomialOptions5
# binomialOptions6
# binomialOptions7
# binomialOptions8
# binomialOptions9
# binomialOptions10
# BlackScholes1
# BlackScholes2
# BlackScholes3
# BlackScholes4
# BlackScholes5
# BlackScholes6
# BlackScholes7
# BlackScholes8
# BlackScholes9
# BlackScholes10
# BlackScholes11
# c++11_cuda1
# c++11_cuda2
# c++11_cuda4
# c++11_cuda5
# c++11_cuda6
# c++11_cuda7
# c++11_cuda8
# c++11_cuda9
# c++11_cuda10
# c++11_cuda11
# cdpAdvancedQuicksort1
# cdpAdvancedQuicksort2
# cdpAdvancedQuicksort3
# cdpAdvancedQuicksort4
# cdpAdvancedQuicksort5
# cdpAdvancedQuicksort6
# cdpAdvancedQuicksort7
# cdpAdvancedQuicksort8
# cdpAdvancedQuicksort9
# cdpAdvancedQuicksort10
# cdpAdvancedQuicksort11
# cdpAdvancedQuicksort12
# cdpAdvancedQuicksort13
# cdpBezierTessellation1
# cdpBezierTessellation2
# cdpBezierTessellation3
# cdpBezierTessellation4
# cdpBezierTessellation5
# cdpBezierTessellation6
# cdpBezierTessellation7
# cdpBezierTessellation8
# cdpBezierTessellation9
# cdpBezierTessellation10
# cdpBezierTessellation11
# cdpLUDecomposition1
# cdpLUDecomposition2
# cdpLUDecomposition3
# cdpLUDecomposition4
# cdpLUDecomposition5
# cdpLUDecomposition6
# cdpLUDecomposition7
# cdpLUDecomposition8
# cdpLUDecomposition9
# cdpLUDecomposition10
# cdpLUDecomposition11
# cdpQuadtree1
# cdpQuadtree2
# cdpQuadtree3
# cdpQuadtree4
# cdpQuadtree5
# cdpQuadtree6
# cdpQuadtree7
# cdpQuadtree8
# cdpQuadtree9
# cdpQuadtree10
# cfd1
# cfd2
# cfd3
# convolutionFFT2D1
# convolutionFFT2D2
# convolutionFFT2D4
# convolutionFFT2D8
# convolutionSeparable1
# convolutionSeparable2
# convolutionSeparable3
# convolutionSeparable4
# convolutionSeparable5
# convolutionSeparable6
# convolutionSeparable7
# convolutionSeparable8
# convolutionSeparable9
# corr1
# corr2
# corr3
# corr4
# corr5
# corr6
# corr7
# corr8
# corr9
# corr10
# cp1
# cp2
# cp3
# cp4
# cp5
# cp6
# cp7
# cp8
# cp9
# cp10
# cutcp1
# cutcp2
# dct8x81
# dct8x82
# dct8x83
# dct8x84
# dct8x85
# dct8x86
# dct8x87
# dct8x88
# dct8x89
# dct8x810
# dwt2d1
# dwt2d2
# dwt2d3
# dwt2d4
# dwt2d5
# dwt2d6
# dwt2d7
# dwt2d8
# dwt2d9
# dwt2d10
# dwt2d11
# dwtHaar1D1
# dwtHaar1D2
# dwtHaar1D3
# dxtc1
# dxtc2
# dxtc3
# dxtc4
# dxtc5
# dxtc6
# dxtc7
# dxtc8
# dxtc9
# dxtc10
# eigenvalues1
# eigenvalues2
# eigenvalues3
# eigenvalues4
# eigenvalues5
# eigenvalues6
# eigenvalues7
# eigenvalues8
# eigenvalues9
# eigenvalues10
# fastWalshTransform1
# fastWalshTransform2
# fastWalshTransform3
# fastWalshTransform4
# fastWalshTransform5
# fastWalshTransform6
# fastWalshTransform7
# fastWalshTransform8
# fastWalshTransform9
# fastWalshTransform10
# fastWalshTransform11
# fastWalshTransform12
# FDTD3d1
# FDTD3d2
# FDTD3d3
# FDTD3d4
# FDTD3d5
# FDTD3d6
# FDTD3d7
# FDTD3d8
# FDTD3d9
# FDTD3d10
# gaussian1
# gaussian2
# gaussian3
# gaussian4
# gaussian5
# gaussian6
# gaussian7
# gaussian8
# gaussian9
# gaussian10
# gaussian11
# gesummv1
# gesummv2
# gesummv3
# gesummv4
# gesummv5
# gesummv6
# gesummv7
# gesummv8
# gesummv9
# gesummv10
# gramschm1
# gramschm2
# gramschm3
# gramschm4
# gramschm5
# gramschm6
# gramschm7
# gramschm8
# gramschm9
# gramschm10
# heartwall1
# heartwall2
# heartwall4
# heartwall6
# heartwall7
# heartwall8
# heartwall9
# heartwall10
# heartwall11
# heartwall12
# histogram1
# histogram2
# histogram3
# histogram4
# histogram5
# histogram6
# histogram7
# histogram8
# histogram9
# histogram10
# hotspot1
# hotspot2
# hotspot3
# hotspot4
# hotspot5
# hotspot6
# hotspot7
# hotspot8
# hotspot3D1
# hotspot3D2
# hotspot3D3
# hotspot3D4
# interval1
# interval2
# interval3
# interval4
# interval5
# interval6
# interval7
# interval8
# interval9
# kmeans1
# kmeans2
# kmeans3
# kmeans4
# lavaMD1
# lavaMD2
# lavaMD3
# lavaMD4
# lavaMD5
# lavaMD6
# lavaMD7
# lavaMD8
# lavaMD9
# lbm1
# lbm2
# lbm3
# lbm4
# lbm5
# lbm6
# lbm7
# lbm8
# lbm9
# leukocyte1
# leukocyte2
# leukocyte3
# leukocyte4
# leukocyte5
# leukocyte6
# leukocyte7
# leukocyte8
# leukocyte9
# leukocyte10
# matrixMul1
# matrixMul2
# matrixMul3
# matrixMul4
# matrixMul5
# matrixMul6
# matrixMul7
# matrixMul8
# matrixMul9
# matrixMul10
# matrixMul11
# mergeSort1
# mergeSort2
# mergeSort3
# mergeSort4
# mergeSort5
# mergeSort6
# mergeSort7
# mergeSort8
# mergeSort9
# mergeSort10
# MonteCarloMultiGPU1
# MonteCarloMultiGPU2
# MonteCarloMultiGPU3
# MonteCarloMultiGPU4
# MonteCarloMultiGPU5
# MonteCarloMultiGPU6
# MonteCarloMultiGPU7
# MonteCarloMultiGPU8
# MonteCarloMultiGPU9
# MonteCarloMultiGPU10
# mri-gridding1
# mri-q1
# mri-q2
# mst1
# mum1
# mum2
# mum3
# mum4
# mum5
# mum6
# mum7
# mum8
# mum9
# mvt1
# mvt2
# mvt3
# mvt4
# mvt5
# mvt6
# mvt7
# mvt8
# mvt9
# mvt10
# myocyte1
# myocyte2
# myocyte3
# myocyte4
# myocyte5
# myocyte6
# myocyte7
# myocyte8
# myocyte9
# myocyte10
# newdelete1
# nn1
# nn2
# nn3
# nn4
# nn5
# nn6
# nn7
# nn8
# nn9
# nn10
# nw1
# nw2
# nw3
# nw4
# nw5
# nw6
# nw7
# nw8
# nw9
# nw10
# particlefilter1
# particlefilter2
# particlefilter3
# particlefilter4
# particlefilter5
# particlefilter6
# particlefilter7
# particlefilter8
# particlefilter9
# particlefilter10
# particlefilter11
# particlefilter12
# pathfinder1
# pathfinder2
# pathfinder3
# pathfinder4
# pathfinder5
# pathfinder6
# pathfinder7
# pathfinder8
# pathfinder9
# pathfinder10
# ptxjit1
# quasirandomGenerator1
# quasirandomGenerator2
# quasirandomGenerator3
# quasirandomGenerator4
# quasirandomGenerator5
# quasirandomGenerator6
# quasirandomGenerator7
# quasirandomGenerator8
# quasirandomGenerator9
# quasirandomGenerator10
# radixSortThrust1
# radixSortThrust2
# radixSortThrust3
# radixSortThrust4
# radixSortThrust5
# radixSortThrust6
# radixSortThrust7
# radixSortThrust8
# radixSortThrust9
# radixSortThrust10
# radixSortThrust11
# recursiveGaussian1
# recursiveGaussian2
# recursiveGaussian3
# recursiveGaussian4
# recursiveGaussian5
# recursiveGaussian6
# recursiveGaussian7
# recursiveGaussian8
# recursiveGaussian9
# recursiveGaussian10
# recursiveGaussian11
# recursiveGaussian12
# recursiveGaussian13
# recursiveGaussian14
# reduction1
# reduction2
# reduction3
# reduction4
# reduction5
# reduction6
# reduction7
# reduction8
# reduction9
# reduction10
# reduction11
# reduction12
# reductionMultiBlockCG1
# reductionMultiBlockCG2
# reductionMultiBlockCG3
# reductionMultiBlockCG4
# reductionMultiBlockCG5
# reductionMultiBlockCG6
# reductionMultiBlockCG7
# reductionMultiBlockCG8
# reductionMultiBlockCG9
# s3d1
# s3d2
# s3d3
# s3d4
# s3d5
# s3d6
# s3d7
# s3d8
# s3d9
# s3d10
# s3d11
# s3d12
# sad13
# scalarProd1
# scalarProd2
# scalarProd3
# scalarProd4
# scalarProd5
# scalarProd6
# scalarProd7
# scalarProd8
# scalarProd9
# scalarProd10
# scan1
# scan2
# scan3
# scan4
# scan5
# scan6
# scan7
# scan8
# scan9
# scan10
# sgemm1
# sgemm2
# segmentationTreeThrust1
# segmentationTreeThrust2
# segmentationTreeThrust3
# segmentationTreeThrust4
# segmentationTreeThrust5
# segmentationTreeThrust6
# segmentationTreeThrust7
# segmentationTreeThrust8
# segmentationTreeThrust9
# segmentationTreeThrust10
# segmentationTreeThrust11
# shfl_scan1
# shfl_scan2
# shfl_scan3
# shfl_scan4
# shfl_scan5
# shfl_scan6
# shfl_scan7
# shfl_scan8
# shfl_scan9
# shfl_scan10
# shfl_scan11
# shfl_scan12
# simpleHyperQ1
# simpleHyperQ2
# simpleHyperQ3
# simpleHyperQ4
# simpleHyperQ5
# simpleHyperQ6
# simpleHyperQ7
# simpleHyperQ8
# simpleHyperQ9
# simpleHyperQ10
# sortingNetworks1
# sortingNetworks2
# sortingNetworks3
# sortingNetworks4
# sortingNetworks5
# sortingNetworks6
# sortingNetworks7
# sortingNetworks8
# sortingNetworks9
# sortingNetworks10
# StreamPriorities1
# StreamPriorities2
# StreamPriorities3
# StreamPriorities4
# StreamPriorities5
# StreamPriorities6
# StreamPriorities7
# StreamPriorities8
# StreamPriorities9
# StreamPriorities10
# StreamPriorities11
# sp1
# sp2
# sp3
# sp4
# spmv1
# spmv2
# srad1
# srad2
# srad3
# srad4
# srad5
# srad6
# srad7
# srad8
# srad9
# srad10
# sssp1
# stencil1
# stencil2
# streamcluster1
# streamcluster2
# streamcluster3
# streamcluster4
# streamcluster5
# streamcluster6
# streamcluster7
# streamcluster8
# streamcluster9
# streamcluster10
# streamcluster11
# syr2k1
# syr2k2
# syr2k3
# syr2k4
# syr2k5
# syr2k6
# syr2k7
# syr2k8
# syr2k9
# syr2k10
# syrk1
# syrk2
# syrk3
# syrk4
# syrk5
# syrk6
# syrk7
# syrk8
# syrk9
# syrk10
# threadFenceReduction1
# threadFenceReduction2
# threadFenceReduction3
# threadFenceReduction4
# threadFenceReduction5
# threadFenceReduction6
# threadFenceReduction7
# threadFenceReduction8
# threadFenceReduction9
# tpacf1
# tpacf2
# tpacf3
# tpacf4
# tpacf5
# tpacf6
# tpacf7
# tpacf8
# tpacf9
# transpose1
# transpose2
# transpose3
# transpose4
# transpose5
# transpose6
# transpose7
# transpose8
# transpose9
# transpose10
# CoMD1
# CoMD2
# CoMD3
# CoMD4
# CoMD5
# CoMD6
# CoMD7
# end
# start
# bitcracker1
# bitcracker2
# bitcracker3
# bitcracker4
# bitcracker5
# bitcracker6
# bitcracker7
# bitcracker8
# bitcracker9
# bitcracker10
# bitcracker11
# bitcracker12
# bitcracker13
# bitcracker14
# bitcracker15
# bitcracker16
# bitcracker17
# bitcracker18
# bitcracker19
# bitcracker20
# blake2b1
# blake2b2
# blake2b3
# blake2b4
# blake2b5
# blake2b6
# blake2b7
# blake2b8
# blake2b9
# blake2b10
# brutehash1
# brutehash2
# brutehash3
# brutehash4
# brutehash5
# brutehash6
# brutehash7
# brutehash8
# brutehash9
# brutehash10
# cuda-hash1
# cuda-hash2
# cuda-hash3
# cuda-hash4
# cuda-hash5
# cuda-hash6
# cuda-hash7
# cuda-hash8
# cuda-hash9
# cuda-hash10
# cuda-hash11
# cudaSha2561
# cudaSha2562
# cudaSha2563
# cudaSha2564
# cudaSha2565
# cudaSha2566
# cudaSha2567
# cudaSha2568
# cudaSha2569
# cudaSha25610
# cudaSha25611
# des1
# des2
# des3
# des4
# des5
# des6
# des7
# des8
# des9
# des10
# hashiru1
# hashiru2
# hashiru3
# hashiru4
# hashiru5
# hashiru6
# hashiru7
# hashiru8
# hashiru9
# hashiru10
# hashrecoverer1
# hashrecoverer2
# hashrecoverer3
# hashrecoverer4
# hashrecoverer5
# hashrecoverer6
# hashrecoverer7
# hashrecoverer8
# hashrecoverer9
# hashsums1
# hashsums2
# hashsums3
# hashsums4
# hashsums5
# hashsums6
# hashsums7
# hashsums8
# hashsums9
# hashsums10
# image-encryption1
# image-encryption2
# image-encryption4
# image-encryption5
# image-encryption6
# image-encryption7
# image-encryption8
# image-encryption9
# image-encryption10
# mario1
# mario2
# mario3
# mario4
# mario6
# mario7
# mario8
# mario9
# mario10
# md5-bruteforcer1
# md5-bruteforcer2
# md5-bruteforcer3
# md5-bruteforcer4
# md5-bruteforcer5
# md5-bruteforcer6
# md5-bruteforcer7
# md5-bruteforcer8
# md5-bruteforcer9
# md5-bruteforcer10
# passordCrack1
# passordCrack2
# passordCrack3
# passordCrack4
# passordCrack5
# passordCrack6
# passordCrack7
# passordCrack8
# passordCrack9
# skein1
# skein2
# skein3
# skein4
# skein5
# skein6
# skein7
# skein8
# skein9
# skein10
# aes1
# aes2
# aes3
# aes4
# aes5
# aes6
# aes7
# aes8
# aes9
# aes10
# lzss_compress1
# lzss_compress2
# lzss_compress3
# lzss_compress4
# lzss_compress5
# lzss_compress6
# lzss_compress7
# lzss_compress8
# lzss_compress9
# lzss_compress10
# lzss_compress11
# end
